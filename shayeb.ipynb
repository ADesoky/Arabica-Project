# %% [markdown]
# <a href="https://colab.research.google.com/github/ADesoky/Arabica-Project/blob/main/shayeb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
'Queen':10,'Ace':11}
#class lkotshena nfsha 
class Card:
  def __init__(self,suit,rank) :
      self.suit=suit
      self.rank=rank
  def __str__(self) :
     return self.rank + self.suit


class Deck: #kotshena bta3tk 
  def __init__(self):
    self.deck = [] # start with an empty list
    for suit in suits:
      for rank in ranks:
        self.deck.append(Card(rank,suit))

 
  def shuffle(self):
    random.shuffle(self.deck)

  def deal(self):
     return self.deck.pop()

    
    
class Player:

    def __init__(self, name):
        self.name = name
        self.player_cards = []

    def add_card_to_player_hand (self, card):
        self.player_cards.append(card)

    def take_card_from_player_hand (self,player,postion):
      
      if postion<=4 and postion>0:
       return player.player_cards.pop(postion)
      else:
        print("akpr 3dd wr2 hwa 12")
         
    def delete_pair(self,card):
        self.player_cards.remove(card)

    def show_cards_in_hands(self):
      for i in self.player_cards:
         print(i)
            
            
def twze3 (deck,player):
  for i in range(12):
    x = deck.deal()
    player.add_card_to_player_hand(x)
  return player   

def remove_pairs(player):
  
  check=False
  l = 0
  while l < len(player.player_cards)-1:
    check=False
    pairs=[]
    for j in range(l+1,len(player.player_cards)):
      if player.player_cards[l]==player.player_cards[j]:
        pairs.append(player.player_cards[j])
        check=True
    if(check):
      pairs.append(player.player_cards[l])
    if(len(pairs)>0):
      for k in pairs:
        player.player_cards.remove(k)
      pairs=[]
      l=0
    else:
      l+=1
  return player
import random
def play(deck):
  
  player1= Player(input("enter Player 1 name"))
  player2= Player(input("enter player 2 name"))
  player3= Player(input("enter player 3  name"))
  player4= Player(input("enter player 4 name"))
  kingCard = Card("Hearts","King")
  player1 = twze3(deck,player1)
  player2 = twze3(deck,player2)
  player3 = twze3(deck,player3)
  player4 = twze3(deck,player4)
  
  randomNumber = random.randint(1,5) #hna bkhli lcomputer yhdd meen ally hib2a m3ah al king randomly
  if randomNumber == 1:
       player1.player_cards.append(kingCard)
  elif randomNumber ==2:
       player2.player_cards.append(kingCard)
  elif randomNumber ==3:
       player3.player_cards.append(kingCard)
  elif randomNumber ==4:
       player4.player_cards.append(kingCard) 
   #hna bshel alarkam aw lwr2 ally shbh b3du 3n tre2 function ana 3amlha
  player1 = remove_pairs(player1)
  player2 = remove_pairs(player2)
  player3 = remove_pairs(player3)
  player4 = remove_pairs(player4)
  #hna hnbd2 nl3b m3 b3d w kol player his7b mn lplayer ltany 
  while True:
    if(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 1 ):
       print("player 4 the looser ")
       break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 1 and len(player4.player_cards) == 0 ):
       print("player 3 the looser ")
       break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 1 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
       print("player 2 the looser ")
       break
    elif(len(player1.player_cards) == 1 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
       print("player 1 the looser ")
       break
    if True:
        print("take number of postion between 1 & 4")
    if(len(player1.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la 
    #ekhtar position llcard 
       choice = int(input('player 1 ekhtar position lcard '))
       card_Chosen = player1.take_card_from_player_hand(player2,choice)
       checker=False
    for i in player1.player_cards:
       if(card_Chosen.rank == i.rank ):
         player1.delete_pair(i)
         checker=True
    if(checker == False):
       player1.add_card_to_player_hand(card_Chosen)
    print('######################')
    if(len(player2.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 2 ekhtar position lcard '))
     card_Chosen = player2.take_card_from_player_hand(player3,choice) # hna hakhud card mn player tany
     checker=False
     for i in player2.player_cards:
       if(card_Chosen.rank == i.rank ):
         player2.delete_pair(i)
         checker=True
     if(checker == False):
       player2.add_card_to_player_hand(card_Chosen)
    
    if(len(player3.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 3 ekhtar position lcard '))
     card_Chosen = player3.take_card_from_player_hand(player4,choice)
     checker=False
     for i in player3.player_cards:
       if(card_Chosen.rank == i.rank ):
         player3.delete_pair(i)
         checker=True
     if(checker == False):
       player3.add_card_to_player_hand(card_Chosen)

    if(len(player4.player_cards) != 0 ):  # b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 4 ekhtar position lcard '))
     card_Chosen = player4.take_card_from_player_hand(player1,choice)
     checker=False
     for i in player4.player_cards:
       if(card_Chosen.rank == i.rank ):
         player4.delete_pair(i)
         checker=True
     if(checker == False):
       player4.add_card_to_player_hand(card_Chosen)
  return deck

# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
'Queen':10,'Ace':11}
#class lkotshena nfsha 
class Card:
    def __init__(self,suit,rank) :
        self.suit=suit
        self.rank=rank
    def __str__(self) :
        return self.rank + self.suit


class Deck: #kotshena bta3tk 
       def __init__(self):
            self.deck = [] # start with an empty list
            for suit in suits:
                for rank in ranks:
                   self.deck.append(Card(rank,suit))

 
       def shuffle(self):
            random.shuffle(self.deck)

       def deal(self):
             return self.deck.pop()

    
    
class Player:

    def __init__(self, name):
        self.name = name
        self.player_cards = []

    def add_card_to_player_hand (self, card):
        self.player_cards.append(card)

    def take_card_from_player_hand (self,player,postion):
      
      if postion<=4 and postion>0:
        return player.player_cards.pop(postion)
      else:
        print("akpr 3dd wr2 hwa 12")
         
    def delete_pair(self,card):
        self.player_cards.remove(card)

    def show_cards_in_hands(self):
        for i in self.player_cards:
            print(i)
            
            
def twze3 (deck,player):
    for i in range(12):
        x = deck.deal()
        player.add_card_to_player_hand(x)
          return player   

def remove_pairs(player):
  
  check=False
l = 0
  while l < len(player.player_cards)-1:
    check=False
    pairs=[]
    for j in range(l+1,len(player.player_cards)):
        if player.player_cards[l]==player.player_cards[j]:
            pairs.append(player.player_cards[j])
        check=True
    if(check):
          pairs.append(player.player_cards[l])
    if(len(pairs)>0):
          for k in pairs:
            player.player_cards.remove(k)
              pairs=[]
                  l=0
    else:
          l+=1
return player

import random
def play(deck):
  
    player1= Player(input("enter Player 1 name "))
    player2= Player(input("enter player 2 name "))
    player3= Player(input("enter player 3  name "))
    player4= Player(input("enter player 4 name "))
    #####################################################
    #bwz3 lwr2 3la players
    player1 = twze3(deck,player1)
    player2 = twze3(deck,player2)
    player3 = twze3(deck,player3)
    player4 = twze3(deck,player4)
    kingCard = Card("Hearts","King")
  
  randomNumber = random.randint(1,5) #hna bkhli lcomputer yhdd meen ally hib2a m3ah al king randomly
    if randomNumber == 1:
           player1.player_cards.append(kingCard)
    elif randomNumber ==2:
           player2.player_cards.append(kingCard)
    elif randomNumber ==3:
           player3.player_cards.append(kingCard)
    elif randomNumber ==4:
           player4.player_cards.append(kingCard) 
   #hna bshel alarkam aw lwr2 ally shbh b3du 3n tre2 function ana 3amlha
      player1 = remove_pairs(player1)
      player2 = remove_pairs(player2)
      player3 = remove_pairs(player3)
      player4 = remove_pairs(player4)
          print(player1,"\n",player2,"\n",player3,"\n",player4)
  #hna hnbd2 nl3b m3 b3d w kol player his7b mn lplayer ltany 
  while True:
    if(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 1 ):
           print("player 4 the looser ")
               break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 1 and len(player4.player_cards) == 0 ):
           print("player 3 the looser ")
               break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 1 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
           print("player 2 the looser ")
               break
    elif(len(player1.player_cards) == 1 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
           print("player 1 the looser ")
               break
    if True:
        print("take number of postion = 1 ")
    if(len(player1.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la 
    #ekhtar position llcard 
       choice = int(input('player 1 ekhtar position lcard '))
       card_Chosen = player1.take_card_from_player_hand(player2,choice)
       checker=False
    for i in player1.player_cards:
        if(card_Chosen.rank == i.rank ):
             player1.delete_pair(i)
                 checker=True
        if(checker == False):
            player1.add_card_to_player_hand(card_Chosen)
    print('######################')
    if(len(player2.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 2 ekhtar position lcard '))
     card_Chosen = player2.take_card_from_player_hand(player3,choice) # hna hakhud card mn player tany
     checker=False
        for i in player2.player_cards:
            if(card_Chosen.rank == i.rank ):
                player2.delete_pair(i)
                 checker=True
            if(checker == False):
                   player2.add_card_to_player_hand(card_Chosen)
    
    if(len(player3.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 3 ekhtar position lcard '))
     card_Chosen = player3.take_card_from_player_hand(player4,choice)
     checker=False
        for i in player3.player_cards:
            if(card_Chosen.rank == i.rank ):
                player3.delete_pair(i)
                 checker=True
            if(checker == False):
                   player3.add_card_to_player_hand(card_Chosen)

    if(len(player4.player_cards) != 0 ):  # b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
        choice = int(input('player 4 ekhtar position lcard '))
        card_Chosen = player4.take_card_from_player_hand(player1,choice)
        checker=False
             for i in player4.player_cards:
                if(card_Chosen.rank == i.rank ):
                     player4.delete_pair(i)
                         checker=True
                if(checker == False):
                       player4.add_card_to_player_hand(card_Chosen)
return deck

print("$$$$$$$$$$$$$$$$$$     Welcome in my cards game   $$$$$$$$$$$$$$$$$$ " ,"\n")
x= input ("********** do you need to know some information about our game  **********").upper()
if x =="YES":    
    print ("   /*/*  i will tell you because i love you and i hope you make some funny moment /*/*    ", "\n")
    print("""             ---- we have 4 players of your friends  ---- 
            ----all of the players take 12 cards from deck and someone take a king-----
          ----each player check the pairs of cards and drop it in his hand ----
         ----after check pairs we will play with our cards  ----
        -------- and player 1 will take a card from player 2 and check the pairs
                after player 2 take a card from player 3 
                after that player 3 take a card from player 4
                finaly player 4 take a card from player 1
                we repeat this process until 3 players have no cards and one player has a one card "king"
                the player has a king card he's the loooser                                 """)
                
else:
     print (" **********     okay lets play you know every thing so     ********** ")


deck1=Deck( )
play(deck1)
# Out:
#   File "<tokenize>", line 23
#     def shuffle(self):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from typing import Counter
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
'Queen':10,'Ace':11}
#class lkotshena nfsha 
class Card:
  def __init__(self,suit,rank) :
      self.suit=suit
      self.rank=rank
  def __str__(self) :
     return self.rank + self.suit


class Deck: #kotshena bta3tk 
  def __init__(self):
    self.deck = [] # start with an empty list
    for suit in suits:
      for rank in ranks:
        self.deck.append(Card(rank,suit))

 
  def shuffle(self):
    random.shuffle(self.deck)

  def deal(self):
     return self.deck.pop()

class Player:

    def __init__(self, name):
        self.name = name
        self.player_cards = []

    def add_card_to_player_hand (self, card):
        self.player_cards.append(card)

    def take_card_from_player_hand (self,player,postion):
      
      if postion<=4 and postion>0:
       return player.player_cards.pop(postion)
      else:
        print("akpr 3dd wr2 hwa 12")
         
    def delete_pair(self,card):
        self.player_cards.remove(card)

    def show_cards_in_hands(self):
      for i in self.player_cards:
         print(i)

def twze3 (deck,player):
  for i in range(12):
    x = deck.deal()
    player.add_card_to_player_hand(x)
  return player

def remove_pairs(player):
  
  check=False
  l = 0
  while l < len(player.player_cards)-1:
    check=False
    pairs=[]
    for j in range(l+1,len(player.player_cards)):
      if player.player_cards[l]==player.player_cards[j]:
        pairs.append(player.player_cards[j])
        check=True
    if(check):
      pairs.append(player.player_cards[l])
    if(len(pairs)>0):
      for k in pairs:
        player.player_cards.remove(k)
      pairs=[]
      l=0
    else:
      l+=1
  return player

import random
def play(deck):
  
  player1= Player(input("Enter Player 1 name "))
  player2= Player(input("Enter player 2 name "))
  player3= Player(input("Enter player 3  name "))
  player4= Player(input("Enter player 4 name "))
  kingCard = Card("Hearts","King")
  player1 = twze3(deck,player1)
  player2 = twze3(deck,player2)
  player3 = twze3(deck,player3)
  player4 = twze3(deck,player4)
  
  randomNumber = random.randint(1,5) #hna bkhli lcomputer yhdd meen ally hib2a m3ah al king randomly
  if randomNumber == 1:
       player1.player_cards.append(kingCard)
  elif randomNumber ==2:
       player2.player_cards.append(kingCard)
  elif randomNumber ==3:
       player3.player_cards.append(kingCard)
  elif randomNumber ==4:
       player4.player_cards.append(kingCard) 
   #hna bshel alarkam aw lwr2 ally shbh b3du 3n tre2 function ana 3amlha
  player1 = remove_pairs(player1)
  player2 = remove_pairs(player2)
  player3 = remove_pairs(player3)
  player4 = remove_pairs(player4)
  #hna hnbd2 nl3b m3 b3d w kol player his7b mn lplayer ltany 
  Counter=0
  while True:
    if(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 1 ):
       print("player 4 the looser ")
       break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 0 and len(player3.player_cards) == 1 and len(player4.player_cards) == 0 ):
       print("player 3 the looser ")
       break
    elif(len(player1.player_cards) == 0 and len(player2.player_cards) == 1 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
       print("player 2 the looser ")
       break
    elif(len(player1.player_cards) == 1 and len(player2.player_cards) == 0 and len(player3.player_cards) == 0 and len(player4.player_cards) == 0 ):
       print("player 1 the looser ")
       break
    if True:
        print("take number of postion between 1 & 4")
        print("------------------------------------------")   
      #  Counter+=1
      #  print (" round "+Counter +=1)
    if(len(player1.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la 
    #ekhtar position llcard 
       choice = int(input('player 1 ekhtar position lcard '))
       card_Chosen = player1.take_card_from_player_hand(player2,choice)
       checker=False
    for i in player1.player_cards:
       if(card_Chosen.rank == i.rank ):
         player1.delete_pair(i)
         checker=True
    if(checker == False):
       player1.add_card_to_player_hand(card_Chosen)
    print('######################')
    if(len(player2.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 2 ekhtar position lcard '))
     card_Chosen = player2.take_card_from_player_hand(player3,choice) # hna hakhud card mn player tany
     checker=False
     for i in player2.player_cards:
       if(card_Chosen.rank == i.rank ):
         player2.delete_pair(i)
         checker=True
     if(checker == False):
       player2.add_card_to_player_hand(card_Chosen)
    print('######################')
    if(len(player3.player_cards) != 0 ):# b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 3 ekhtar position lcard '))
     card_Chosen = player3.take_card_from_player_hand(player4,choice)
     checker=False
     for i in player3.player_cards:
       if(card_Chosen.rank == i.rank ):
         player3.delete_pair(i)
         checker=True
     if(checker == False):
       player3.add_card_to_player_hand(card_Chosen)
    print('######################')
    if(len(player4.player_cards) != 0 ):  # b tcheck lw lplayer lesa m3ah wr2 wla la
    #ekhtar position lcard 
     choice = int(input('player 4 ekhtar position lcard '))
     card_Chosen = player4.take_card_from_player_hand(player1,choice)
     checker=False
     for i in player4.player_cards:
       if(card_Chosen.rank == i.rank ):
         player4.delete_pair(i)
         checker=True
     if(checker == False):
       player4.add_card_to_player_hand(card_Chosen)
     print('######################')  
  return deck

print("$$$$$$$$$$$$$$$$$$     Welcome in my cards game   $$$$$$$$$$$$$$$$$$ " ,"\n")
x= input ("********** do you need to know some information about our game  **********").upper()
if x =="YES":    
    print ("   /*/*  i will tell you because i love you and i hope you make some funny moment /*/*    ", "\n")
    print("""                    ---- we have 4 players of your friends  ---- 
    ***************************************************************************************
            ----all of the players take 12 cards from deck and someone take a king-----
              ----each player check the pairs of cards and drop it in his hand ----
              *****************************************************************
                   ----after check pairs we will play with our cards  ----
             -------- and player 1 will take a card from player 2 and check the pairs-------
                           after player 2 take a card from player 3 
                         after that player 3 take a card from player 4
                          finaly player 4 take a card from player 1
                    ******************************************************            
                we repeat this process until 3 players have no cards and 
            one player has a one card "king" the player has a king card he's the loooser           
            *****************************************************************************""")
                
else:
     print (" **********     okay lets play you know every thing so     ********** ")


deck1=Deck( )
play(deck1)
# Out:
# $$$$$$$$$$$$$$$$$$     Welcome in my cards game   $$$$$$$$$$$$$$$$$$
#
#    /*/*  i will tell you because i love you and i hope you make some funny moment /*/*
#
#                     ---- we have 4 players of your friends  ----
#     ***************************************************************************************
#             ----all of the players take 12 cards from deck and someone take a king-----
#               ----each player check the pairs of cards and drop it in his hand ----
#               *****************************************************************
#                    ----after check pairs we will play with our cards  ----
#              -------- and player 1 will take a card from player 2 and check the pairs-------
#                            after player 2 take a card from player 3
#                          after that player 3 take a card from player 4
#                           finaly player 4 take a card from player 1
# ...
